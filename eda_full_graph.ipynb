# %%
import pandas as pd
import plotly.express as px

# %%
from pathlib import Path

# %%
JSONS_DIR = Path('quy_work', 'Output', 'jsons')
JSONS_DIR
# Out:
# PosixPath('quy_work/Output/jsons')

# %%
food_log_tagged = pd.read_json(Path(JSONS_DIR, 'food_log_tagged.json'))

# %%
food_log_tagged
# Out:
#                 datetime       date      time           time_begin time_end  \
# 0    2020-02-13 18:00:00 2020-02-13  18:00:00  2020-02-13 18:00:00     None
# 1    2020-02-13 20:30:00 2020-02-13  20:30:00  2020-02-13 20:30:00     None
# 2    2020-02-13 20:30:00 2020-02-13  20:30:00  2020-02-13 20:30:00     None
# 3    2020-02-14 07:10:00 2020-02-14  07:10:00  2020-02-14 07:10:00     None
# 4    2020-02-14 07:10:00 2020-02-14  07:10:00  2020-02-14 07:10:00     None
# ...                  ...        ...       ...                  ...      ...
# 1359 2020-02-26 18:30:00 2020-02-26     18:30  2020-02-26 18:30:00     None
# 1360 2020-02-27 10:30:00 2020-02-27     10:30  2020-02-27 10:30:00     None
# 1361 2020-02-27 11:30:00 2020-02-27     11:30  2020-02-27 11:30:00     None
# 1362 2020-02-27 11:30:00 2020-02-27     11:30  2020-02-27 11:30:00     None
# 1363 2020-02-28 08:00:00 2020-02-28      8:00  2020-02-28 08:00:00     None
#
# ...

# %%
pd.read_json(Path(JSONS_DIR, 'glucose.json'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pd.read_json(Path(JSONS_DIR, 'glucose.json'))
#
# File ~/Documents/Courses/Spring_2025/DSC_106/.venv/lib/python3.11/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~/Documents/Courses/Spring_2025/DSC_106/.venv/lib/python3.11/site-packages/pandas/io/json/_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
# ...

# %%
# Get all timestamps x amount of time before food and x amount of time after food
# Combine these timestamps with the ot
